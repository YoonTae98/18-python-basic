# %%
# 사칙연산
1 + 1
# Out:
# 2

# %%
"1" + "1"
# Out:
# '11'

# %%
1-2
# Out:
# -1

# %%
5 / 2
# Out:
# 2.5

# %%
4 / 2
# Out:
# 2.0

# %%
# 소수점 이하를 버리는 연산자 // (몫)
print(6 // 2)
print(4 // 2)
# Out:
# 3
# 2

# %%
# 나머지를 구하는 연산자 %
print(5 % 2)
print(7 % 3)
# Out:
# 1
# 1

# %%
# 거듭제곱을 구하는 **연산자
print(2 ** 10)
print(10 ** 10)
# Out:
# 1024
# 10000000000

# %%
# 값을 정수롷 만들기
print(int(3.3))
print(int(5 / 2))
print(int("1"))
# Out:
# 3
# 2
# 1

# %%
# 객체의 자료형 알아내기
print(type(10))
print(type("1"))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# 실수 계산하기
3.5 + 2.1
# Out:
# 5.6

# %%
# 실수와 정수를 함께 계산하면
4.2 + 5
# Out:
# 9.2

# %%
# 값을 실수로 만들기
print(float(5))
print(float(1+2))
print(float("5.3"))
# Out:
# 5.0
# 3.0
# 5.3

# %%
# 괄호 사용하기
35 + 1 * 2
# Out:
# 37

# %%
(35 + 1) * 2
# Out:
# 72

# %%
print(int(0.2467 * 12 + 4.159))
# Out:
# 7

# %%
AP = 102
print(AP * 0.6 + 225)
# Out:
# 286.2
