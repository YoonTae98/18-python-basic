# %%
가격 = int(input())
쿠폰이름 = input()

if 쿠폰이름[:4] == "Cash":
    할인 = int(쿠폰이름[4:])
    print(가격 - 할인)

# %%
국어, 영어, 수학, 과학 = map(int, input().split())
평균 = (국어 + 영어 + 수학 + 과학) / 4
if 평균 >= 80:
    print("합격")
else:
    print("불합격")

# %%
age = int(input())
balace = 9000
if 12 >= age >= 7:
    print(balace - 650)
elif 18 >= age:
    print(balace - 1050)
else:
    print(balace - 1250)

# %%
a = int(input())
for i in range(0, 10, 1):
    result = a * i
    print(f"{a} * {i} = {result}")

# %%
금액 = int(input())
while 금액 >= 1350:
    print(금액 - 1350)
    금액 -= 1350

# %%
start, stop = map(int, input().split())

i = start

while True:
    if i > stop or i < 1 or i > 200 or stop < 10 or stop > 200:
        break
    elif i % 10 == 3:
        i += 1
        continue
    print(i, end=' ')
    i += 1

# %%
# for i in range(high):
#     for j in range(a):
#         if j == (a - 1):
#             print('*' * a)
#             continue
#         elif j == (high - 1):
#             print('*', end='')
#             if j < i+(high - 1):
#                 print('*', end='')
#                 if j < a:
#                     print('*', end='')
#         elif i < j:
#             print(' ', end='')
#     print()



high = int(input())
max = 3 + (2 * (high - 2))

for i in range(high):
    for j in range(max):
        if j < high - i - 1:
            print(' ', end='')
        elif j < high - i - 1 + (2 * i + 1):
            print('*', end='')
    print()

# high = 3 일때
# i = 0 1 2 
# j = 0 1 2 3 4
# - - 2        i = 0, j = 0, 1 에는 ' ' j = 2 에는 * 출력  j < 2 ' ', j(2~) < 3 '*'
# - 1 2 3      i = 1  j = 0 에는 ' ' j = 1, 2, 3 에는 * 출력 j < 1 ' ', j(1~) < 4 '*'
# 0 1 2 3 4    i = 2  j = j = 0, 1, 2, 3, 4 에는 * 출력 j < 0 ' ', j(0~) < 5 '*'
# 공백 -= 1
# * += 1
# i+(high-1)

# %%
high = int(input())
max = 3 + (2 * (high - 2))

for i in range(high):
    for j in range(max):
        if j < high - i - 1:
            print(' ', end='')
        elif j < high - i - 1 + (2 * i + 1):
            print('*', end='')
    print()

# %%
first, second = map(int, input().split())
for i in range(first, second+1):
    if i % 5 == 0 and i % 7 == 0:
        print("FizzBuzz")
    elif i % 5 == 0:
        print("Fizz")
    elif i % 7 == 0:
        print("Buzz")
    else:
        print(i)

# %%
# unit 23. 연습문제

a = [[[0 for col in range(3)] for row in range(4)] for depth in range(2)]
print(a)

# %%
# 지뢰찾기

col, row = map(int, input().split())

matrix = []
for i in range(row):
    matrix.append(list(input()))

# %%
print(matrix)

# %%
for i in range(row):
    result = ""
    for j in range(col):
        if matrix[i][j] == "*":
            result += "*"
        else:
            지뢰수 = 0
            for x in range(-1, 2):
                for y in range(-1, 2):
                    find1 = x + i
                    find2 = y + j
                    if 0 <= find1 < row and 0 <= find2 < col:
                        if matrix[find1][find2] == "*":
                            지뢰수 += 1
            result += str(지뢰수)
    print(result)

# %%
# 실생활에 함수로 만들 수 있는 것(버스 잔액 계산기)

def 버스비(소지금, 요금):
    횟수 = 소지금 // 요금
    거스름돈 = 소지금 % 요금
    return 횟수, 거스름돈


소지금 = int(input("교통카드 잔액을 입력하세요: "))
요금 = int(input("버스 요금을 입력하세요: "))

횟수, 거스름돈 = 버스비(소지금, 요금)

print("버스를 탈 수 있는 횟수:", 횟수, "번")
print("버스를 타고 남는 잔액:", 거스름돈, "원")

# %%
# 실생활에 클래스로 만들 수 있는 것(헬스장 회원관리)

class Gym:
    def __init__(self, name, age, year, month, membership):
        self.name = name
        self.age = age
        self.year = year
        self.month = month
        self.membership = membership
        self.end_month = month + membership
        self.end_year = year

        if self.end_month > 12:
            self.end_month -= 12
            self.end_year += 1

    def check_member(self):
        print("회원 이름:", self.name)
        print("나이:", self.age)
        print("회원권:", self.membership, "개월")
        print("등록 날짜:", self.year, "년", self.month, "월")
        print("만료 날짜:", self.end_year, "년", self.end_month, "월")


member1 = Gym("철수", 20, 2026, 9, 3)
member2 = Gym("영이", 25, 2026, 6, 12)
member1.check_member()
print("-----------")
member2.check_member()

# %%
# 2. 당신은 커피숍 계산 프로그램을 함수로 만들려고 한다. 
# 커피가 주문되고 계산이 이루어지는 함수와 일별, 월별 매출과 수익을 보여주는 함수를 자유롭게 만들어주세요

def coffee(cash, cup):
    재고 = 100
    가격 = 1500
    if 가격 * int(cup) < 재고 * 가격:
        print("재고가 부족합니다.")
    elif int(cash) < 가격:
        print("지불금액이 부족합니다.")
    elif 가격 * int(cup) >= 재고 * 가격:
        재고 -= int(cup)
        잔돈 = int(cash) - int(cup) * 가격
        return

# %%
# 커피숍 계산 프로그램

재고 = 100
가격 = 1500
원가 = 700

일매출 = 0
일수익 = 0

월매출 = 0
월수익 = 0


# 커피 주문 및 계산 함수
def coffee(cash, cup):
    global 재고, 일매출, 일수익, 월매출, 월수익

    cash = int(cash)
    cup = int(cup)

    # 재고 확인
    if cup > 재고:
        print("재고가 부족합니다.")
        return

    # 결제금액 확인
    총금액 = 가격 * cup

    if cash < 총금액:
        print("지불금액이 부족합니다.")
        return

    # 계산
    재고 -= cup
    잔돈 = cash - 총금액

    # 매출과 수익 계산
    매출 = 총금액
    수익 = (가격 - 원가) * cup

    일매출 += 매출
    일수익 += 수익

    월매출 += 매출
    월수익 += 수익

    print("주문 수량:", cup, "잔")
    print("결제 금액:", 총금액, "원")
    print("잔돈:", 잔돈, "원")
    print("남은 재고:", 재고, "잔")

    return 잔돈


# 일별 매출과 수익을 보여주는 함수
def daily_sales():
    print("\n===== 일별 매출 현황 =====")
    print("일 매출:", 일매출, "원")
    print("일 수익:", 일수익, "원")


# 월별 매출과 수익을 보여주는 함수
def monthly_sales():
    print("\n===== 월별 매출 현황 =====")
    print("월 매출:", 월매출, "원")
    print("월 수익:", 월수익, "원")


# 재고 확인 함수
def stock():
    print("\n===== 재고 현황 =====")
    print("남은 커피:", 재고, "잔")


coffee(5000, 2)
coffee(10000, 3)

daily_sales()
monthly_sales()
stock()

# %%
재고 = 100
일매출 = 0
일수익 = 0

def coffee(cash, cup, 재고, 일매출, 일수익):

    가격 = 1500
    원가 = 700
    총금액 = 가격 * cup

    if cup > 재고:
        print("재고가 부족합니다.")
        return 재고, 일매출, 일수익

    if cash < 총금액:
        print("돈이 부족합니다.")
        return 재고, 일매출, 일수익

    재고 -= cup
    일매출 += 총금액
    일수익 += (가격 - 원가) * cup

    잔돈 = cash - 총금액

    print("잔돈:", 잔돈, "원")

    return 재고, 일매출, 일수익


재고, 일매출, 일수익 = coffee(
    5000, 2, 재고, 일매출, 일수익
)

print("재고:", 재고)
print("일매출:", 일매출)
print("일수익:", 일수익)

# %%
# 커피숍 계산 프로그램

재고 = 100
가격 = 1500
원가 = 700
일매출 = 0
일수익 = 0
월매출 = 0
월수익 = 0

def coffee(cash, cup, 재고, 일매출, 일수익, 월매출, 월수익):

    cash = int(cash)
    cup = int(cup)

    if cup > 재고:
        print("재고가 부족합니다.")
        return 재고, 일매출, 일수익, 월매출, 월수익
    총금액 = 가격 * cup

    if cash < 총금액:
        print("지불금액이 부족합니다.")
        return 재고, 일매출, 일수익, 월매출, 월수익

    잔돈 = cash - 총금액
    재고 -= cup
    매출 = 총금액
    수익 = (가격 - 원가) * cup
    일매출 += 매출
    일수익 += 수익
    월매출 += 매출
    월수익 += 수익

    print(cup, "잔 주문", "판매 금액:", 총금액, "원", "잔돈:", 잔돈, "원")
    return 재고, 일매출, 일수익, 월매출, 월수익

def end_day(일매출, 일수익):
    print("- 하루 마감 -")
    print("오늘 매출:", 일매출, "원", "오늘 수익:", 일수익, "원")
    일매출 = 0
    일수익 = 0
    return 일매출, 일수익

def monthly_sales(월매출, 월수익):
    print("- 이번 달 매출 -")
    print("월 매출:", 월매출, "원", "월 수익:", 월수익, "원")

print("- 1일차 -")
coffee(5000, 2, 재고, 일매출, 일수익, 월매출, 월수익)
coffee(10000, 3, 재고, 일매출, 일수익, 월매출, 월수익)
end_day(일매출, 일수익)

print("- 2일차 -")
coffee(5000, 1, 재고, 일매출, 일수익, 월매출, 월수익)
coffee(10000, 4, 재고, 일매출, 일수익, 월매출, 월수익)
end_day(일매출, 일수익)

print("= 월말 정산 =")
monthly_sales(월매출, 월수익)
print("남은 재고:", 재고, "잔")

# %%
# 심사문제
x = input().split()
del x[-5:]
tuple(x)

# 심사문제(2)
첫번째문자열 = input()
두번째문자열 = input()
첫번째문자열[1::2] + 두번째문자열[::2]

# unit 12. 심사문제
first = input().split()
second = input().split()
print(dict(zip(first, second)))

# unit 13. 심사문제
가격 = int(input())
쿠폰이름 = input()

if 쿠폰이름[:4] == "Cash":
    할인 = int(쿠폰이름[4:])
    print(가격 - 할인)

# unit 14. 심사문제
국어, 영어, 수학, 과학 = map(int, input().split())
평균 = (국어 + 영어 + 수학 + 과학) / 4

if 0 <= 국어 <= 100 and 0 <= 영어 <= 100 and 0 <= 수학 <= 100 and 0 <= 과학 <= 100:
    if 평균 >= 80:
        print("합격")
    else:
        print("불합격")
else:
    print("잘못된 점수")  

# unit 15. 심사문제
age = int(input())
balance = 9000

if 12 >= age >= 7:
    balance = balance - 650
elif 18 >= age:
    balance = balance - 1050
else:
    balance = balance - 1250

print(balance)

# unit 16. 심사문제
x = int(input())

for i in range(1,10):
    print(f"{x} * {i} = {x * i}")

# unit 17. 심사문제
금액 = int(input())
요금 = 1350

while 금액 >= 요금:
    금액 -= 요금
    print(금액)

# unit 18. 심사문제
start, stop = map(int, input().split())

i = start

while True:
    if i > stop or i < 1 or i > 200 or stop < 10 or stop > 200:
        break
    if i % 10 == 3:
        i += 1
        continue
    print(i, end=' ')
    i += 1

# unit 19. 심사문제 교수님 풀이

num = int(input())

for i in range(num):
    print((" " * ((num-1) - i)) + "*" * (2 * i + 1))

# unit 20. 심사문제

first, second = map(int, input().split())

for i in range(first, second + 1):
    if i % 5 == 0 and i % 7 == 0:
        print("FizzBuzz")
    elif i % 5 == 0:
        print("Fizz")
    elif i % 7 == 0:
        print("Buzz")
    else:
        print(i) 

# unit 22. 심사문제(2번째 풀이)

first, second = map(int, input().split())

result = [2 ** val for i, val in enumerate(range(first, second + 1)) if i != 1 and i != second - first - 1]
result

# unit 23. 심사문제

col, row = map(int, input().split())

matrix = []
for i in range(row):
    matrix.append(list(input()))

for i in range(row):
    result = ""
    for j in range(col):
        if matrix[i][j] == "*":
            result += "*"
        else:
            지뢰수 = 0
            for x in range(-1, 2):
                for y in range(-1, 2):
                    find1 = i + x
                    find2 = j + y
                    if 0 <= find1 < row and 0 <= find2 < col:
                        if matrix[find1][find2] == "*":
                            지뢰수 += 1
            result += str(지뢰수)
    print(result)

# unit 24-6 심사문제
# 51900;83000;158000;367500;250000;59200;128500;1304000

price = input().split(";")
up_price = list(map(int, price))
result = sorted(up_price, reverse=True)
for i in result:
    print(f"{i:9,}")

# unit 25. 심사문제
# alpha bravo charlie delta echo foxtrot golf

keys = input().split()
values = map(int, input().split())

x = dict(zip(keys, values))

x = {key: value for key, value in x.items() if key != "delta" and value != 30}
print(x)

# unit 26. 심사문제

first, second = map(int,input().split())

a = {i for i in range(1, first + 1) if first % i == 0}
b = {i for i in range(1, second + 1) if second % i == 0}

divisor = a & b

result = 0
if type(divisor) == set:
    result = sum(divisor)

print(result)

# unit 29. 심사문제

x, y = map(int, input().split())

def calc(num_a, num_b):
    return num_a + num_b, num_a - num_b, num_a * num_b, num_a / num_b

a, s, m, d = calc(x, y)
print("덧셈: {0}, 뺄셈: {1}, 곱셈 {2}, 나눗셈 {3}".format(a, s, m, d))

# unit 30. 심사문제
# 76 82 89 84 가장 높은 점수 가장 낮은 점수 평균 점수 평균점수는 실수로

korean, english, mathematics, science = map(int, input().split())

def get_min_max_score(*args):
    return min(args), max(args) 
def get_average(**kwargs):
    return sum(kwargs.values()) / len(kwargs)

min_score, max_score = get_min_max_score(korean, english, mathematics, science)
average_score = get_average(korean=korean, english=english,
                            mathematics=mathematics, science=science)
print('낮은 점수: {0:.2f}, 높은 점수: {1:.2f}, 평균 점수: {2:.2f}'.format(min_score, max_score, average_score))

min_score, max_score = get_min_max_score(english, science)
average_score = get_average(english=english, science=science)
print('낮은 점수: {0:.2f}, 높은 점수: {1:.2f}, 평균 점수: {2:.2f}'.format(min_score, max_score, average_score))

# unit 31. 심사문제

def fib(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    else:
        return fib(n - 1) + fib(n - 2)

n = int(input())
print(fib(n))

# unit 32. 심사문제
# 97.xlsx 98.docx 99.docx 100.xlsx 101.docx 102.docx

files = input().split()

print(list(map(lambda x: '{:03d}'.format(int(x.split('.')[0])) + '.' + x.split('.')[1], files)))

# unit 34. 심사문제
# 511.68 334.0 298
# 1803.68 1184.0 645

class Annie:
    def __init__(self, health, mana, ability_power):
        self.health = health
        self.mana = mana
        self.ability_power = ability_power

    def tibbers(self):
        print(f"티버: 피해량 {self.ability_power * 0.65 + 400}")

health, mana, ability_power = map(float, input().split())

x = Annie(health=health, mana=mana, ability_power=ability_power)
x.tibbers()

# %%
# 1
a = "python"
b = "coding"
a[1::2] + b[::2]

# %%
# 2
a = input().split()
b = list(map(int, input().split()))
students = dict(zip(a, b))
students

# %%
나이 = int(input())

if 나이 < 7:
    print("0원")
elif 나이 < 13:
    print("500원")
elif 나이 < 19:
    print("1000원")
else:
    print("1500원")

# %%
start, stop = map(int, input().split())

for i in range(start, stop+1):
    if i % 15 == 0:
        print("FizzBuzz")
    elif i % 3 == 0:
        print("Fizz")
    elif i % 5 == 0:
        print("Buzz")
    else:
        print(i)

# %%
b = map(int, input().split(";"))

result = sorted(b, reverse=True)
for i in result:
    print(f"{i:9,}")

# %%
keys = input().split()
values = map(int, input().split())

x = dict(zip(keys, values))

x = {key: value for key, value in x.items() if value >= 5000}

# %%
print(x)

# %%
inventory = {
    "노트북": 1500000,
    "마우스": 30000,
    "키보드": 50000,
    "모니터": 300000
}


def checkout(**items):
    total = 0

    for name, count in items.items():
        if name in inventory:
            price = inventory[name] * count
            print(f"{name} {count}개: {price:,}원")
            total += price
        else:
            print(f"판매하지 않는 상품입니다: {name}")

    print(f"총 결제 금액: {total:,}원")
    print()


checkout(노트북=1, 마우스=2)
checkout(모니터=2, 패드=1)

# %%
def analyze_scores(*args):
    average = sum(args) / len(args)
    count = 0

    for score in args:
        if score >= average:
            count += 1

    print(f"평균: {average}")
    print(f"평균 이상인 수의 개수: {count}")


scores = map(int, input().split())
analyze_scores(*scores)
