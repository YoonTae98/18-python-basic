# %%
# 세미콜론
print('Hello, world'); print("1234")
# Out:
# Hello, world
# 1234

# %%
# 한 줄 주석
# 출력하라
print("hello world")
# Out:
# hello world

# %%
# 블록 주석(ctrl+/)
# print("hello world")
# print("hello world")
# print("hello world")

# %%
# 들여쓰기
a = 5
if a == 10:
    print("10입니다")
