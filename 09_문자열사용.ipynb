# %%
# 문자열 사용
hello = "Hello World"
hello
# Out:
# 'Hello World'

# %%
hello = '안녕하세요'
hello
# Out:
# '안녕하세요'

# %%
hello = '''Hello, Python'''
hello
# Out:
# 'Hello, Python'

# %%
python = """Python Programming"""
python
# Out:
# 'Python Programming'

# %%
# 여러 줄로 된 문자열 사용하기
hello = '''Hello, world
안녕하세요
Python입니다'''
print(hello)
# Out:
# Hello, world
# 안녕하세요
# Python입니다

# %%
# 문자열 안에 작은따옴표나 큰따옴표 포함하기
s = "Python isn's difficult"
print(s)
# Out:
# Python isn's difficult

# %%
s = 'He said "Python is easy"'
print(s)
# Out:
# He said "Python is easy"

# %%
single_quote = '''"안녕하세요.
'파이썬'입니다.
'''
print(single_quote)
# Out:
# "안녕하세요.
# '파이썬'입니다.

# %%
s = """'Python' is a "programming language"
that lets you work quikly
and
integrate systems more effectively.
"""
print(s)
# Out:
# 'Python' is a "programming language"
# that lets you work quikly
# and
# integrate systems more effectively.
