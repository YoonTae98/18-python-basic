# %%
# if 조건문 사용하기

# %%
x = 10
if x == 10:
    print('10입니다.')
# Out:
# 10입니다.

# %%
# if조건문을 사용할 주의할 점
if x = 10:
# Out:
#   Cell In[2], line 2
#     if x = 10:
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
# if 조건문에서 코드를 생략하기
x = 10
if x == 10:
    pass

# %%
# 조건문과 들여쓰기

x = 10
if x == 10:
    print("x에 들어있는 숫자는")

print("10입니다.")
# Out:
# x에 들어있는 숫자는
# 10입니다.

# %%
# 중첩 if조건문 사용하기

x = 15

if x >= 10:
    print("10이상입니다.")

    if x == 15:
        print("15입니다.")
    if x == 20:
        print("20입니다.")
# Out:
# 10이상입니다.
# 15입니다.

# %%
# 사용자가 입력한 값에 if 조건문 사용하기
x = int(input())

if x == 10:
    print("10입니다.")
if x == 20:
    print("20입니다.")
# Out:
# 10입니다.

# %%
# 연습문제

x = 5
if x != 10:
    print('ok')
# Out:
# ok

# %%
# 심사문제

가격 = int(input())
쿠폰이름 = input()

if 쿠폰이름[:4] == "Cash":
    할인 = int(쿠폰이름[4:])
    print(가격 - 할인)
# Out:
# 24000
